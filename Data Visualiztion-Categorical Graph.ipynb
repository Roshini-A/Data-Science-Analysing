# %% [markdown]
# # Categorical Data Plot
# 1.factorplot
#
# 2.boxplot
#
# 3.violinplot
#
# 4.barplot
#
# 5.stripplot
#
# 6.swarmplot
#
# 7.countplot

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
stores=pd.read_csv("C:\\Users\\LENOVO\\Downloads\\Stores.csv")
tips=sns.load_dataset("tips")

# %%
stores.head()
# Out:
#    Unnamed: 0 StoreCode         StoreName     StoreType Location  \
# 0           1    STR101  Electronics Zone  Electronincs    Delhi
# 1           2    STR102      Apparel Zone       Apparel    Delhi
# 2           3    STR103       Super Bazar  Super Market    Delhi
# 3           4    STR104      Super Market  Super Market    Delhi
# 4           5    STR105     Central Store  Super Market    Delhi
#
#    OperatingCost  Staff_Cnt  TotalSales  Total_Customers  AcqCostPercust  ...  \
# 0           21.0         60       160.0              110            3.90  ...
# 1           21.0         60       160.0              110            3.90  ...
# 2           22.8         40       108.0               93            3.85  ...
# 3           21.4         60       258.0              110            3.08  ...
# 4           18.7         80       360.0              175            3.15  ...
#
#    OnlinePresence  Tenure  StoreSegment   Range       Exp   Exp2  \
# ...

# %% [markdown]
# # barplot

# %%
sns.barplot(x='Location',y='TotalSales',data=stores);
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-b78199a39008> in <module>
# ----> 1 sns.barplot(x='Location',y='TotalSales',data=stores);
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3148                           estimator, ci, n_boot, units, seed,
#    3149                           orient, color, palette, saturation,
# -> 3150                           errcolor, errwidth, capsize, dodge)
#    3151
#    3152     if ax is None:
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py in __init__(self, x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge)
# ...

# %%
sns.barplot("sex","total_bill",data=tips)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-c52b13a65a84> in <module>
# ----> 1 sns.barplot("sex","total_bill",data=tips)
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3148                           estimator, ci, n_boot, units, seed,
#    3149                           orient, color, palette, saturation,
# -> 3150                           errcolor, errwidth, capsize, dodge)
#    3151
#    3152     if ax is None:
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py in __init__(self, x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge)
# ...

# %%
sns.barplot(x='smoker',y='total_bill',data=tips,estimator=np.sum);
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-a2d3d994a52a> in <module>
# ----> 1 sns.barplot(x='smoker',y='total_bill',data=tips,estimator=np.sum);
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3148                           estimator, ci, n_boot, units, seed,
#    3149                           orient, color, palette, saturation,
# -> 3150                           errcolor, errwidth, capsize, dodge)
#    3151
#    3152     if ax is None:
#
# ...

# %% [markdown]
# # countplot
# this is same as barplot except it explicitly counting number of occurences,which is why we only pass x value

# %%
sns.countplot(x='sex',data=tips)

# %%
sns.countplot(x='smoker',data=tips)

# %% [markdown]
# # boxplot

# %%
sns.boxplot(x="day",y="total_bill",data=tips,palette='coolwarm')

# %%
sns.boxplot(x="Location",y="TotalSales",data=stores,palette='husl')

# %%
#can do the entire datafram with orient='-h'
sns.boxplot(data=tips,palette='rainbow',orient='-h')

# %% [markdown]
# # violinplot

# %%
sns.violinplot(x="day",y="total_bill",data=tips,palette='rainbow')

# %%
sns.violinplot(x="day",y="total_bill",data=tips,hue='sex',palette='Set1')

# %% [markdown]
# # stripplot
#   stripplot will draw scatterplot where one variable is categorical.A strip plot good on its own,but it is also a good component to box or violon plot where you want to show all observation along with underlying distribution

# %%
sns.stripplot(x='day',y='total_bill',data=tips,jitter=False)

# %%
sns.stripplot(x='day',y='total_bill',data=tips,jitter=True)

# %%
sns.stripplot(x='day',y='total_bill',data=tips,jitter=True,hue='sex',palette='Set1')

# %%
sns.stripplot(x='day',y='total_bill',data=tips,jitter=True,hue='sex')

# %%
sns.stripplot(x='day',y='total_bill',data=tips,jitter=True,hue='sex',palette='Set1',split=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:2784: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# # swarmplot
# swarmplot is same as stripplot but the points are adjusted such that they don't overlap.This gives a better representation of
# distribution of values,although it does not scale as well to large obsevations

# %%
sns.swarmplot(x='day',y='total_bill',data=tips,hue='sex',palette='Set1',split=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:2974: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)

# %%
sns.swarmplot(x='day',y='total_bill',data=tips)

# %% [markdown]
# # Combining Categorical Data

# %%
sns.swarmplot(x='day',y='total_bill',data=tips,hue='sex',palette='Set1',split=True)
sns.violinplot(x='day',y='total_bill',data=tips,hue='sex')

# %% [markdown]
# # factorplot
# it is most general categorical plot.It can take in kind parameter to adjust the plot type:

# %%
sns.factorplot(x='sex',y='total_bill',data=tips,kind="bar")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-7e5c98c9c4ad> in <module>
# ----> 1 sns.factorplot(x='tip',y='total_bill',data=tips,kind="bar")
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py in factorplot(*args, **kwargs)
#    3677     kwargs.setdefault("kind", "point")
#    3678
# -> 3679     return catplot(*args, **kwargs)
#    3680
#    3681
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py in catplot(x, y, hue, data, row, col, col_wrap, estimator, ci, n_boot, units, seed, order, hue_order, row_order, col_order, kind, height, aspect, orient, color, palette, legend, legend_out, sharex, sharey, margin_titles, facet_kws, **kwargs)
#    3763
#    3764     # Draw the plot onto the facets
# -> 3765     g.map_dataframe(plot_func, x, y, hue, **plot_kws)
#    3766
# ...

# %%
sns.factorplot(x='sex',y='total_bill',data=tips,kind="violin")
#kind:strip,bar,box,violin,swarm,boxen

# %%
sns.factorplot(x='sex',y='total_bill',data=tips,kind="swarm")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:3669: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
sns.factorplot(x='sex',y='total_bill',data=tips,kind="strip")

# %%
sns.factorplot(x='sex',y='total_bill',data=tips,kind="boxen")

# %%
sns.factorplot(x='sex',y='total_bill',data=tips,kind="box")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:3669: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %% [markdown]
# # PieChart

# %%
cars=['Audi','BMW','Ford','Tesla','Jaguar','Mercedes']
data=[21,17,35,19,12,14]
plt.pie(data,labels=cars)
plt.show()

# %%
car=pd.read_csv("C:\\Users\\LENOVO\\Downloads\\Car_sales.csv")
car["Manufacturer"].fillna("BMW",inplace=True)
carg=car.groupby("Manufacturer").mean()[["Sales in thousands"]].reset_index()

# %%
plt.figure(figsize=(12,12))
plt.pie(carg["Sales in thousands"],labels=carg["Manufacturer"]);
