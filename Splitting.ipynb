# %%
import pandas as pd
import numpy as np

# %%
sales=pd.read_csv("C:\\Users\\LENOVO\Downloads\\Sales_Outliers.csv")

# %%
sales.head()
# Out:
#    Unnamed: 0 Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           0           FDA15         9.30          Low Fat         0.016047
# 1           1           DRC01         5.92          Regular         0.019278
# 2           2           FDN15        17.50          Low Fat         0.016760
# 3           3           FDX07        19.20          Regular         0.000000
# 4           4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# ...

# %%
sales.isnull().sum()
# Out:
# Unnamed: 0                      0
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                     0
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
sales["Item_Weight"].fillna(sales["Item_Weight"].mean(),inplace=True)
sales.isnull().sum()
sales=sales.iloc[:,1:]

# %%
sales.drop("Unnamed: 0",axis=1,inplace=True)

# %%
#SPLITTING THE DATA
#the column that needs to be predicted is dependant and rests columns  are independent
sales.head()
# Out:
#    Item_Weight Item_Fat_Content  Item_Visibility              Item_Type  \
# 0         9.30          Low Fat         0.016047                  Dairy
# 1         5.92          Regular         0.019278            Soft Drinks
# 2        17.50          Low Fat         0.016760                   Meat
# 3        19.20          Regular         0.000000  Fruits and Vegetables
# 4         8.93          Low Fat         0.000000              Household
#
#    Item_MRP Outlet_Identifier  Outlet_Establishment_Year Outlet_Size  \
# 0  249.8092            OUT049                       1999      Medium
# 1   48.2692            OUT018                       2009      Medium
# 2  141.6180            OUT049                       1999      Medium
# 3  182.0950            OUT010                       1998      Medium
# 4   53.8614            OUT013                       1987        High
#
#   Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# ...

# %%
x=sales.iloc[:,:10]
y=sales.iloc[:,10]

# %%
x
# Out:
#       Item_Weight Item_Fat_Content  Item_Visibility              Item_Type  \
# 0           9.300          Low Fat         0.016047                  Dairy
# 1           5.920          Regular         0.019278            Soft Drinks
# 2          17.500          Low Fat         0.016760                   Meat
# 3          19.200          Regular         0.000000  Fruits and Vegetables
# 4           8.930          Low Fat         0.000000              Household
# ...           ...              ...              ...                    ...
# 8518        6.865          Low Fat         0.056783            Snack Foods
# 8519        8.380          Regular         0.046982           Baking Goods
# 8520       10.600          Low Fat         0.035186     Health and Hygiene
# 8521        7.210          Regular         0.145221            Snack Foods
# 8522       14.800          Low Fat         0.044878            Soft Drinks
#
# ...

# %%
y
# Out:
# 0       3735.1380
# 1        443.4228
# 2       2097.2700
# 3        732.3800
# 4        994.7052
#           ...
# 8518    2778.3834
# 8519     549.2850
# 8520    1193.1136
# 8521    1845.5976
# 8522     765.6700
# Name: Item_Outlet_Sales, Length: 8523, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test=train_test_split(x,y,test_size=0.3,random_state=42)#splits 30 percent of data to X_test,Y_test

# %%
X_train
# Out:
#       Item_Weight Item_Fat_Content  Item_Visibility              Item_Type  \
# 1921     7.720000          Regular         0.147904  Fruits and Vegetables
# 655     19.750000          Low Fat         0.014301              Household
# 2229    12.857645          Regular         0.054221                 Breads
# 2537    19.350000          Low Fat         0.118342            Snack Foods
# 3528    18.350000          Regular         0.092150           Frozen Foods
# ...           ...              ...              ...                    ...
# 5734     9.395000          Regular         0.286345  Fruits and Vegetables
# 5191    15.600000          Low Fat         0.117575           Frozen Foods
# 5390    17.600000          Low Fat         0.018944     Health and Hygiene
# 860     20.350000          low fat         0.054363            Snack Foods
# 7270    16.350000               LF         0.016993              Household
#
# ...

# %%
Y_train
# Out:
# 1921     117.8466
# 655     1230.3984
# 2229    4933.5780
# 2537    1789.6704
# 3528    3872.9586
#           ...
# 5734     280.9676
# 5191    1301.6390
# 5390    6145.3340
# 860     1649.8524
# 7270     965.4100
# Name: Item_Outlet_Sales, Length: 5966, dtype: float64

# %%
x.shape
# Out:
# (8523, 10)

# %%
print((8523*30)/100)
X_test.shape
# Out:
# 2556.9
# (2557, 10)

# %%
print((8523*70)/100)
Y_train.shape
# Out:
# 5966.1
# (5966,)

# %%
#X_train andd Y_train are used to train the Machine Learning Model
#X_test used to generate new prediction from Machine Learning Model
#Y_test used to check how accurately Mchine Learning Model generates the prediction
#train_test_split() is to split
