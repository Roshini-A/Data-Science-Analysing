# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("C:\\Users\\LENOVO\\Downloads\\Advertising_data.csv")

# %%
data.head()
# Out:
#       TV  radio  newspaper  sales
# 0  230.1   37.8       69.2   2210
# 1   44.5   39.3       45.1   1040
# 2   17.2   45.9       69.3    930
# 3  151.5   41.3       58.5   1850
# 4  180.8   10.8       58.4   1290

# %% [markdown]
# # SIMPLE LINEAR REGRESSION

# %%
#turning data into array
x=data["TV"].values.reshape(-1,1)
y=data["sales"].values.reshape(-1,1)

# %%
x
# Out:
# array([[230.1],
#        [ 44.5],
#        [ 17.2],
#        [151.5],
#        [180.8],
#        [  8.7],
#        [ 57.5],
#        [120.2],
#        [  8.6],
#        [199.8],
#        [ 66.1],
#        [214.7],
#        [ 23.8],
#        [ 97.5],
#        [204.1],
#        [195.4],
#        [ 67.8],
#        [281.4],
#        [ 69.2],
#        [147.3],
#        [218.4],
#        [237.4],
#        [ 13.2],
#        [228.3],
#        [ 62.3],
#        [262.9],
#        [142.9],
#        [240.1],
#        [248.8],
#        [ 70.6],
#        [292.9],
#        [112.9],
#        [ 97.2],
#        [265.6],
#        [ 95.7],
#        [290.7],
#        [266.9],
#        [ 74.7],
#        [ 43.1],
#        [228. ],
#        [202.5],
#        [177. ],
#        [293.6],
#        [206.9],
#        [ 25.1],
#        [175.1],
#        [ 89.7],
#        [239.9],
#        [227.2],
#        [ 66.9],
#        [199.8],
#        [100.4],
#        [216.4],
#        [182.6],
#        [262.7],
# ...

# %%
x.shape
# Out:
# (200, 1)

# %%
y
# Out:
# array([[2210],
#        [1040],
#        [ 930],
#        [1850],
#        [1290],
#        [ 720],
#        [1180],
#        [1320],
#        [ 480],
#        [1060],
#        [ 860],
#        [1740],
#        [ 920],
#        [ 970],
#        [1900],
#        [2240],
#        [1250],
#        [2440],
#        [1130],
#        [1460],
#        [1800],
#        [1250],
#        [ 560],
#        [1550],
#        [ 970],
#        [1200],
#        [1500],
#        [1590],
#        [1890],
#        [1050],
#        [2140],
#        [1190],
#        [ 960],
#        [1740],
#        [ 950],
#        [1280],
#        [2540],
#        [1470],
#        [1010],
#        [2150],
#        [1660],
#        [1710],
#        [2070],
#        [1290],
#        [ 850],
#        [1490],
#        [1060],
#        [2320],
#        [1480],
#        [ 970],
#        [1140],
#        [1070],
#        [2260],
#        [2120],
#        [2020],
#        [2370],
#        [ 550],
#        [1320],
# ...

# %%
y.shape
# Out:
# (200, 1)

# %%
#plotting scatter plot
plt.figure(figsize=(10,10))
plt.scatter(x,y,c="black")
plt.xlabel("Money spent on TV")
plt.ylabel("Sales")
plt.show()

# %%
#splitting the data
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
X_test
# Out:
# array([[163.3],
#        [195.4],
#        [292.9],
#        [ 11.7],
#        [220.3],
#        [ 75.1],
#        [216.8],
#        [ 50. ],
#        [222.4],
#        [175.1],
#        [ 31.5],
#        [ 56.2],
#        [234.5],
#        [  5.4],
#        [139.5],
#        [170.2],
#        [  7.3],
#        [197.6],
#        [ 75.3],
#        [237.4],
#        [229.5],
#        [ 67.8],
#        [ 38. ],
#        [250.9],
#        [ 69. ],
#        [ 53.5],
#        [213.5],
#        [139.3],
#        [ 87.2],
#        [  8.4],
#        [199.8],
#        [ 69.2],
#        [198.9],
#        [ 16.9],
#        [280.7],
#        [238.2],
#        [ 48.3],
#        [273.7],
#        [117.2],
#        [ 27.5]])

# %%
Y_test
# Out:
# array([[1690],
#        [2240],
#        [2140],
#        [ 730],
#        [2470],
#        [1260],
#        [2230],
#        [ 840],
#        [1150],
#        [1490],
#        [ 950],
#        [ 870],
#        [1190],
#        [ 530],
#        [1030],
#        [1170],
#        [ 550],
#        [1660],
#        [1130],
#        [1890],
#        [1970],
#        [1250],
#        [1090],
#        [2220],
#        [ 930],
#        [ 810],
#        [2170],
#        [1340],
#        [1060],
#        [ 570],
#        [1060],
#        [1130],
#        [2370],
#        [ 870],
#        [1610],
#        [2070],
#        [1160],
#        [2080],
#        [1190],
#        [ 690]], dtype=int64)

# %%
#fitting linear regression to the training set
from sklearn.linear_model import LinearRegression
reg=LinearRegression()
reg.fit(X_train,Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
X_test
# Out:
# array([[163.3],
#        [195.4],
#        [292.9],
#        [ 11.7],
#        [220.3],
#        [ 75.1],
#        [216.8],
#        [ 50. ],
#        [222.4],
#        [175.1],
#        [ 31.5],
#        [ 56.2],
#        [234.5],
#        [  5.4],
#        [139.5],
#        [170.2],
#        [  7.3],
#        [197.6],
#        [ 75.3],
#        [237.4],
#        [229.5],
#        [ 67.8],
#        [ 38. ],
#        [250.9],
#        [ 69. ],
#        [ 53.5],
#        [213.5],
#        [139.3],
#        [ 87.2],
#        [  8.4],
#        [199.8],
#        [ 69.2],
#        [198.9],
#        [ 16.9],
#        [280.7],
#        [238.2],
#        [ 48.3],
#        [273.7],
#        [117.2],
#        [ 27.5]])

# %%
Y_test
# Out:
# array([[1690],
#        [2240],
#        [2140],
#        [ 730],
#        [2470],
#        [1260],
#        [2230],
#        [ 840],
#        [1150],
#        [1490],
#        [ 950],
#        [ 870],
#        [1190],
#        [ 530],
#        [1030],
#        [1170],
#        [ 550],
#        [1660],
#        [1130],
#        [1890],
#        [1970],
#        [1250],
#        [1090],
#        [2220],
#        [ 930],
#        [ 810],
#        [2170],
#        [1340],
#        [1060],
#        [ 570],
#        [1060],
#        [1130],
#        [2370],
#        [ 870],
#        [1610],
#        [2070],
#        [1160],
#        [2080],
#        [1190],
#        [ 690]], dtype=int64)

# %%
reg.predict(X_test)
# Out:
# array([[1471.79439447],
#        [1621.15483966],
#        [2074.81974329],
#        [ 766.40363149],
#        [1737.01387659],
#        [1061.40214319],
#        [1720.72846979],
#        [ 944.61251159],
#        [1746.78512067],
#        [1526.69948024],
#        [ 858.53250423],
#        [ 973.46094648],
#        [1803.08609845],
#        [ 737.08989926],
#        [1361.05362825],
#        [1503.89991073],
#        [ 745.93054866],
#        [1631.39138108],
#        [1062.33273786],
#        [1816.57972123],
#        [1779.8212316 ],
#        [1027.43543758],
#        [ 888.77683114],
#        [1879.39486173],
#        [1033.01900563],
#        [ 960.89791838],
#        [1705.37365767],
#        [1360.12303358],
#        [1117.70312097],
#        [ 751.04881937],
#        [1641.62792249],
#        [1033.9496003 ],
#        [1637.44024646],
#        [ 790.59909302],
#        [2018.05346817],
#        [1820.30209992],
#        [ 936.70245686],
#        [1985.48265458],
# ...

# %%
#calaculating accuracy
y_pred=reg.predict(X_test)
from sklearn.metrics import r2_score
r2_score(Y_test,y_pred)
# Out:
# 0.6766954295627077

# %%
#calculating coefficient
reg.coef_
#y=mx+c
# Out:
# array([[4.65297337]])

# %%
#calculating intercept
reg.intercept_
# Out:
# array([711.96384306])

# %%
plt.figure(figsize=(10,10))
plt.scatter(x,y,c="black")
plt.plot(
    X_test,
    y_pred,
    c="blue",
    linewidth=2
)
plt.xlabel("Money spent on TV")
plt.ylabel("Sales")
plt.title("Prediction point VS Actual Point")
# Out:
# Text(0.5, 1.0, 'Prediction point VS Actual Point')

# %%
output=reg.predict([[250]])
output
# Out:
# array([[1875.2071857]])

# %% [markdown]
# # MULTIPLE REGRESSION

# %%
x=data.drop(["sales"],axis=1)
y=data["sales"].values.reshape(-1,1)

# %%
x
# Out:
#         TV  radio  newspaper
# 0    230.1   37.8       69.2
# 1     44.5   39.3       45.1
# 2     17.2   45.9       69.3
# 3    151.5   41.3       58.5
# 4    180.8   10.8       58.4
# ..     ...    ...        ...
# 195   38.2    3.7       13.8
# 196   94.2    4.9        8.1
# 197  177.0    9.3        6.4
# 198  283.6   42.0       66.2
# 199  232.1    8.6        8.7
#
# [200 rows x 3 columns]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
#fitting linear regression to the training set
from sklearn.linear_model import LinearRegression
multiple_reg=LinearRegression()
multiple_reg.fit(X_train,Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
#predicting test set result
y_pred=multiple_reg.predict(X_test)

# %%
y_pred
# Out:
# array([[1640.80242032],
#        [2088.98820871],
#        [2155.38431791],
#        [1060.8502562 ],
#        [2211.23732599],
#        [1310.5591724 ],
#        [2105.71919163],
#        [ 746.10103446],
#        [1360.63458054],
#        [1515.50696689],
#        [ 904.83199241],
#        [ 665.32831249],
#        [1434.55448651],
#        [ 890.34933289],
#        [ 968.95902804],
#        [1216.49438591],
#        [ 873.62839734],
#        [1626.50725772],
#        [1027.75958206],
#        [1883.10910344],
#        [1956.03665331],
#        [1325.10346424],
#        [1233.62069482],
#        [2130.69513175],
#        [ 782.74030508],
#        [ 580.95744781],
#        [2075.75323145],
#        [1198.13807742],
#        [ 918.34957628],
#        [ 850.66991002],
#        [1246.64676934],
#        [1000.33769512],
#        [2138.76709023],
#        [1224.96636755],
#        [1826.66153761],
#        [2013.76626654],
#        [1405.51400528],
#        [2085.41118629],
# ...

# %%
X_test
# Out:
#         TV  radio  newspaper
# 95   163.3   31.6       52.9
# 15   195.4   47.7       52.9
# 30   292.9   28.3       43.2
# 158   11.7   36.9       45.2
# 128  220.3   49.0        3.2
# 115   75.1   35.0       52.7
# 69   216.8   43.9       27.2
# 170   50.0   11.6       18.4
# 174  222.4    3.4       13.1
# 45   175.1   22.5       31.5
# 66    31.5   24.6        2.2
# 182   56.2    5.7       29.7
# 165  234.5    3.4       84.8
# 78     5.4   29.9        9.4
# 186  139.5    2.1       26.6
# 177  170.2    7.8       35.2
# 56     7.3   28.1       41.4
# 152  197.6   23.3       14.2
# 82    75.3   20.3       32.5
# 68   237.4   27.5       11.0
# 124  229.5   32.3       74.2
# 16    67.8   36.6      114.0
# 148   38.0   40.3       11.9
# 93   250.9   36.5       72.3
# 65    69.0    9.3        0.9
# 60    53.5    2.0       21.4
# 84   213.5   43.0       33.8
# 67   139.3   14.5       10.2
# 125   87.2   11.8       25.9
# 132    8.4   27.2        2.1
# 9    199.8    2.6       21.2
# ...

# %%
Y_test
# Out:
# array([[1690],
#        [2240],
#        [2140],
#        [ 730],
#        [2470],
#        [1260],
#        [2230],
#        [ 840],
#        [1150],
#        [1490],
#        [ 950],
#        [ 870],
#        [1190],
#        [ 530],
#        [1030],
#        [1170],
#        [ 550],
#        [1660],
#        [1130],
#        [1890],
#        [1970],
#        [1250],
#        [1090],
#        [2220],
#        [ 930],
#        [ 810],
#        [2170],
#        [1340],
#        [1060],
#        [ 570],
#        [1060],
#        [1130],
#        [2370],
#        [ 870],
#        [1610],
#        [2070],
#        [1160],
#        [2080],
#        [1190],
#        [ 690]], dtype=int64)

# %%
from sklearn.metrics import r2_score
r2_score(Y_test,y_pred)
# Out:
# 0.899438024100912

# %%
multiple_reg.coef_#2D array
# Out:
# array([[ 4.47295175, 18.91950542,  0.27611143]])

# %%
x.columns
# Out:
# Index(['TV', 'radio', 'newspaper'], dtype='object')

# %%
new=[]
for i in range(3):
    new.append(multiple_reg.coef_[0][i])

# %%
new
# Out:
# [4.472951746871632, 18.919505423437638, 0.27611143413671435]

# %%
pd.Series(multiple_reg.coef_[0],index=x.columns).sort_values(ascending=True)
# Out:
# newspaper     0.276111
# TV            4.472952
# radio        18.919505
# dtype: float64

# %%
data["TV_News"]=data["TV"]+data["newspaper"]

# %%
data.head()
# Out:
#       TV  radio  newspaper  sales  TV_News
# 0  230.1   37.8       69.2   2210    299.3
# 1   44.5   39.3       45.1   1040     89.6
# 2   17.2   45.9       69.3    930     86.5
# 3  151.5   41.3       58.5   1850    210.0
# 4  180.8   10.8       58.4   1290    239.2

# %%
x=data.drop(["sales","TV","newspaper"],axis=1)
y=data["sales"].values.reshape(-1,1)

# %%
x
# Out:
#      radio  TV_News
# 0     37.8    299.3
# 1     39.3     89.6
# 2     45.9     86.5
# 3     41.3    210.0
# 4     10.8    239.2
# ..     ...      ...
# 195    3.7     52.0
# 196    4.9    102.3
# 197    9.3    183.4
# 198   42.0    349.8
# 199    8.6    240.8
#
# [200 rows x 2 columns]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression
m_reg=LinearRegression()
m_reg.fit(X_train,Y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
X_test
# Out:
#      radio  TV_News
# 95    31.6    216.2
# 15    47.7    248.3
# 30    28.3    336.1
# 158   36.9     56.9
# 128   49.0    223.5
# 115   35.0    127.8
# 69    43.9    244.0
# 170   11.6     68.4
# 174    3.4    235.5
# 45    22.5    206.6
# 66    24.6     33.7
# 182    5.7     85.9
# 165    3.4    319.3
# 78    29.9     14.8
# 186    2.1    166.1
# 177    7.8    205.4
# 56    28.1     48.7
# 152   23.3    211.8
# 82    20.3    107.8
# 68    27.5    248.4
# 124   32.3    303.7
# 16    36.6    181.8
# 148   40.3     49.9
# 93    36.5    323.2
# 65     9.3     69.9
# 60     2.0     74.9
# 84    43.0    247.3
# 67    14.5    149.5
# 125   11.8    113.1
# 132   27.2     10.5
# 9      2.6    221.0
# 18    20.5     87.5
# 55    49.4    258.9
# 75    43.7    106.3
# 150   13.9    317.7
# 104   34.3    243.5
# 135   47.0     56.8
# 137   28.9    333.4
# 164   14.7    122.6
# 76     1.6     48.2

# %%
Y_test
# Out:
# array([[1690],
#        [2240],
#        [2140],
#        [ 730],
#        [2470],
#        [1260],
#        [2230],
#        [ 840],
#        [1150],
#        [1490],
#        [ 950],
#        [ 870],
#        [1190],
#        [ 530],
#        [1030],
#        [1170],
#        [ 550],
#        [1660],
#        [1130],
#        [1890],
#        [1970],
#        [1250],
#        [1090],
#        [2220],
#        [ 930],
#        [ 810],
#        [2170],
#        [1340],
#        [1060],
#        [ 570],
#        [1060],
#        [1130],
#        [2370],
#        [ 870],
#        [1610],
#        [2070],
#        [1160],
#        [2080],
#        [1190],
#        [ 690]], dtype=int64)

# %%
y_pred=m_reg.predict(X_test)
y_pred
# Out:
# array([[1711.95207118],
#        [2120.47740764],
#        [2169.15036808],
#        [1119.94029365],
#        [2036.31289015],
#        [1391.1591218 ],
#        [2038.06792477],
#        [ 742.89194254],
#        [1319.40647455],
#        [1517.58558346],
#        [ 813.49792973],
#        [ 718.33874634],
#        [1677.80613411],
#        [ 821.95527156],
#        [1000.69213845],
#        [1264.80074005],
#        [ 936.61552502],
#        [1553.30287455],
#        [1057.96958149],
#        [1780.59331668],
#        [2097.96904171],
#        [1649.06417125],
#        [1147.28257444],
#        [2252.12542442],
#        [ 710.55884043],
#        [ 608.95910985],
#        [2037.01910934],
#        [1138.60076007],
#        [ 937.43636346],
#        [ 758.07761805],
#        [1243.91451957],
#        [ 974.51903975],
#        [2194.4520707 ],
#        [1445.77686496],
#        [1847.85791598],
#        [1874.19717302],
#        [1289.66849686],
#        [2167.71115558],
# ...

# %%
from sklearn.metrics import r2_score
r2_score(Y_test,y_pred)
# Out:
# 0.8427246480614342
